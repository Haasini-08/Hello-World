# %% [markdown]
# <a href="https://colab.research.google.com/github/Haasini-08/Hello-World/blob/main/Python%20input%20basic%20biodata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input()
age=input()
Address=input()
print("My Name is:",name)
print("My age is:",age)
print("My Address is",Address)
# Out:
# Haasini
# 17
# Madipakkam,Chennai.
# My Name is: Haasini
# My age is: 17
# My Address is Madipakkam,Chennai.
