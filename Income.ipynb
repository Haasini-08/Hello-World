# %% [markdown]
# <a href="https://colab.research.google.com/github/Haasini-08/Hello-World/blob/main/Income.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
income=int(input())

if(income>10000):
 print("Not applicable for the scholaship")
else:
  print("Applicable for the scholarship")
# Out:
# 7000
# Applicable for the scholarship
