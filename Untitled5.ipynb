# %% [markdown]
# <a href="https://colab.research.google.com/github/Haasini-08/Hello-World/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
b=2
c=1
d=a*b*c
e=a+b+c
f=d/e
print(d)
print(e)
print(f)
# Out:
# 6
# 6
# 1.0
