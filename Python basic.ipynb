# %% [markdown]
# <a href="https://colab.research.google.com/github/Haasini-08/Hello-World/blob/main/Python%20basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Life is Good")
a=10
b=20
c=a+b
print(c)
d=int("10")
print(d)
# Out:
# Life is Good
# 30
# 10
